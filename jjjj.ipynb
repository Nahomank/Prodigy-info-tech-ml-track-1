# %%
import pandas as pd
import numpy as nd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("train.csv")

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data=pd.read_csv('train.csv')
data=data[['LotArea','YearBuilt','MasVnrArea','PoolArea','SalePrice','MoSold', 'YrSold','Id']]

# %%
data
# Out:
#       LotArea  YearBuilt  MasVnrArea  PoolArea  SalePrice  MoSold  YrSold  \
# 0        8450       2003       196.0         0     208500       2    2008
# 1        9600       1976         0.0         0     181500       5    2007
# 2       11250       2001       162.0         0     223500       9    2008
# 3        9550       1915         0.0         0     140000       2    2006
# 4       14260       2000       350.0         0     250000      12    2008
# ...       ...        ...         ...       ...        ...     ...     ...
# 1455     7917       1999         0.0         0     175000       8    2007
# 1456    13175       1978       119.0         0     210000       2    2010
# 1457     9042       1941         0.0         0     266500       5    2010
# 1458     9717       1950         0.0         0     142125       4    2010
# 1459     9937       1965         0.0         0     147500       6    2008
#
#         Id
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# # SECTION II: Data visualization

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# Select only numeric columns
non_numeric_columns = data.select_dtypes(exclude=['float64', 'int64']).columns
data_numeric = data.drop(columns=non_numeric_columns)
# Calculate the correlation matrix
correlation_matrix = data_numeric.corr()
# Create a heatmap
plt.figure(figsize=(10, 5)) 
sns.heatmap(correlation_matrix[['SalePrice', 'YearBuilt',]], annot=True, cmap='YlGnBu', fmt=".4f")
plt.title("Correlation Diagram with SalePrice,")
# Out:
# Text(0.5, 1.0, 'Correlation Diagram with SalePrice,')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the colormap
colormap = plt.cm.PuBu

# Create a larger figure
plt.figure(figsize=(18, 18))

# Set the title
plt.title("Hierarchical Relationship of Features in Train Data", size=19)

# Generate the heatmap
sns.heatmap(data.corr(), linewidths=0.1, square=True, cmap=colormap, linecolor="blue", annot=True, annot_kws={"size": 10})

# Display the plot
plt.show()

# %% [markdown]
# Stage III. Linear Regression

# %%
x=data[['LotArea','YearBuilt','PoolArea','GarageCars','YrSold','MasVnrArea','GrLivArea','Id','OverallQual']]
y=data[['SalePrice']]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer

# Load your data
data = pd.read_csv('train.csv')

# Select features and target
x = data[['LotArea','YearBuilt','PoolArea','GarageCars','YrSold','MasVnrArea','GrLivArea','Id','OverallQual']]
y = data[['SalePrice']]

# Impute missing values
imputer = SimpleImputer(strategy='mean')  # You can use different strategies like 'mean', 'median', 'most_frequent', etc.
x_imputed = imputer.fit_transform(x)

# Instantiate the Linear Regression model
model = LinearRegression()

# Fit the model to your training data
model.fit(x_imputed, y)

# Make predictions
y_pred = model.predict(x_imputed)

# Calculate the difference between actual prices and predicted values
difference = y - y_pred

# Create a DataFrame to compare accurate prices, machine-predicted values, and differences
prediction_difference = pd.DataFrame({
    'Accurate Price': y.squeeze(),
    'Machine Predicted Value': y_pred.squeeze(),
    'Difference': difference.squeeze()
})

# Display the first few rows of the DataFrame
prediction_difference.head()
# Out:
#    Accurate Price  Machine Predicted Value    Difference
# 0          208500            227853.351443 -19353.351443
# 1          181500            167187.570535  14312.429465
# 2          223500            231957.830444  -8457.830444
# 3          140000            205192.139084 -65192.139084
# 4          250000            298285.922126 -48285.922126

# %%
from sklearn.impute import SimpleImputer

# Instantiating a SimpleImputer to handle missing values
imputer = SimpleImputer(strategy='mean')

# Imputing missing values in the training and test sets
x_train_imputed = imputer.fit_transform(x_train)
x_test_imputed = imputer.transform(x_test)

# Instantiating a Linear Regression model
model = LinearRegression()

# Training the model using the training data with imputed values
model.fit(x_train_imputed, y_train)

# Making predictions on the test set
predicted_values = model.predict(x_test_imputed)

# Visualizing actual vs. predicted values
plt.scatter(y_test, predicted_values, color='blue', alpha=0.7, label='Actual vs. Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Comparison of Actual vs. Predicted Sale Prices')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import r2_score

# Calculate R-squared Score (as percentage)
accuracy = r2_score(y_test, predicted_values) * 100

print("Accuracy of the Prediction machine model is: {:.2f}%".format(accuracy))
# Out:
# Accuracy of the Prediction machine model is: 80.28%
